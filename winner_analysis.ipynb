# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("athlete_events.csv")
df2 = pd.read_csv("NOC_regions.csv")
merged_df = pd.merge(df1, df2, on='NOC')

# %%
medalists_df = merged_df[merged_df['Medal'].isin(['Gold', 'Silver', 'Bronze'])]

# %%
# top countries with most medals
top_countries = medalists_df.groupby('region')['Medal'].count().sort_values(ascending=False)
sns.barplot(top_countries.index[:10], top_countries.values[:10])
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_countries_df = medalists_df[medalists_df['region'].isin(['USA', 'Russia', 'Germany'])]

# %%
top_countries_medals_per_year = pd.pivot_table(top_countries_df, values=['ID'],
                                columns=['region'],
                                index=['Year'],
                                aggfunc='count')

# %%
top_countries_medals_per_year
# Out:
#             ID
# region Germany Russia    USA
# Year
# 1896      32.0    NaN   20.0
# 1900      45.0    NaN   63.0
# 1904      16.0    NaN  394.0
# 1906      30.0    NaN   24.0
# 1908      21.0    3.0   65.0
# 1912      53.0   14.0  107.0
# 1920       NaN    NaN  194.0
# 1924       NaN    NaN  194.0
# 1928      82.0    NaN  102.0
# 1932      57.0    NaN  223.0
# 1936     231.0    NaN  112.0
# 1948       NaN    NaN  168.0
# 1952      52.0  117.0  164.0
# 1956      54.0  206.0  149.0
# 1960      98.0  211.0  152.0
# 1964     126.0  221.0  177.0
# 1968     119.0  229.0  173.0
# 1972     283.0  259.0  195.0
# 1976     337.0  342.0  175.0
# 1980     311.0  496.0   30.0
# 1984     199.0   56.0  361.0
# 1988     342.0  366.0  214.0
# 1992     236.0  279.0  238.0
# 1994      40.0   36.0   19.0
# 1996     124.0  115.0  259.0
# 1998      44.0   52.0   34.0
# 2000     118.0  187.0  242.0
# 2002      61.0   38.0   84.0
# 2004     149.0  189.0  263.0
# 2006      54.0   41.0   52.0
# 2008      99.0  142.0  317.0
# 2010      54.0   25.0   97.0
# 2012      94.0  140.0  248.0
# 2014      36.0   68.0   64.0
# 2016     159.0  115.0  264.0

# %%
top_countries_medals_per_year = top_countries_medals_per_year[top_countries_medals_per_year.index >= 1952]

# %%
top_countries_medals_per_year.plot(linestyle='-', marker='o', alpha=0.9, figsize=(15,5), linewidth=2)
plt.legend(facecolor='white', framealpha=1, edgecolor='black')
plt.xlabel('Year')
plt.xticks(top_countries_medals_per_year.index)
plt.ylabel('Number of Medals')
plt.title('Medal Achievements of Top 3 Countries with Highest Total Medals from 1952-2016')
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# Inference
# * from 1956 to 1968, Russia dominated the olympics with USA following
# * from 1996 till 2016, USA topped the chart for country with the most medals
# * Germany only topped the medals ranking once during the 1972 olympics with Russia closely behind

# %%
# List of countries by continent
asia = ['Afghanistan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Timor-Leste',
        'Georgia', 'India', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Japan', 'Kyrgyzstan', 'Kuwait', 'Laos', 'Lebanon',
        'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestine',
        'Philippines', 'Qatar', 'Saudi Arabia', 'South Korea', 'Syria', 'Taiwan', 'Sri Lanka', 'Tajikistan', 'Thailand',
         'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen', 'Azerbaijan', 'Indonesia']


europe = ['Albania', 'Andorra', 'Angola', 'Antigua', 'Armenia', 'Austria', 'Azerbaijan',
          'Belgium', 'Bosnia and Herzegovina', 'Belize', 'Belarus', 'Czech Republic', 'Bulgaria',
          'Croatia', 'Cyprus', 'Denmark', 'Hungary', 'Iceland', 'Italy', 'Kazakhstan', 'Kosovo', 'Finland',
          'France', 'Georgia', 'Germany', 'Greece', 'Ireland', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta',
          'Latvia', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal',
          'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden','Turkey',
          'Switzerland', 'Ukraine', 'UK', 'Macedonia', 'Virgin Islands, British']

africa = ['Angola', 'Algeria', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cape Verde', 'Cameroon',
          'Democratic Republic of the Congo', 'Chad', 'Central African Republic', 'Republic of Congo',
          'Democratic Republic of the Congo', 'Gabon', 'Gambia', 'Ghana', 'Equatorial Guinea', 'Guinea',
          'Guinea-Bissau', 'Morocco', 'Egypt', 'Kenya', 'Libya', 'Mali', 'Senegal', 'Solomon Islands',
          'Somalia', 'South Sudan', 'Tunisia', 'Zimbabwe', 'Zambia', 'Sudan', 'Sierra Leone', 'Comoros',
          'Ivory Coast', 'Djibouti', 'Eritrea', 'Swaziland', 'Ethiopia', 'Lesotho', 'Liberia', 'Madagascar',
          'Malawi', 'Mauritania', 'Mauritius', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
          'Sao Tome and Principe', 'Seychelles', 'South Africa', 'Tanzania', 'Togo', 'Uganda']

north_america = ['Antigua', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica',
                 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica',
                  'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts', 'Saint Vincent', 'Saint Lucia', 'Trinidad',
                 'USA', 'Cayman Islands', 'American Samoa', 'Puerto Rico', 'Aruba', 'Bermuda']

south_america = ['Argentina', 'Boliva', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay',
                 'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'Curacao']

oceania = ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand',
           'Palau', 'Papua New Guinea', 'Samoa', 'Tonga', 'Cook Islands', 'Individual Olympic Athletes',
           'Vanuatu', 'nan', 'Guam', 'US']

# Create a new column 'continent' in the 'df' DataFrame and assign continent values
merged_df['continent'] = pd.np.where(merged_df['region'].isin(europe), 'Europe',
                pd.np.where(merged_df['region'].isin(africa), 'Africa',
                pd.np.where(merged_df['region'].isin(asia), 'Asia',
                pd.np.where(merged_df['region'].isin(north_america), 'North America',
                pd.np.where(merged_df['region'].isin(south_america), 'South America',
                pd.np.where(merged_df['region'].isin(oceania), 'Oceania','unknown')))))  )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:39: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   merged_df['continent'] = pd.np.where(merged_df['region'].isin(europe), 'Europe',
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:40: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(merged_df['region'].isin(africa), 'Africa',
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:41: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(merged_df['region'].isin(asia), 'Asia',
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:42: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(merged_df['region'].isin(north_america), 'North America',
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:43: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(merged_df['region'].isin(south_america), 'South America',
# C:\Users\HP\AppData\Local\Temp\ipykernel_2692\831432286.py:44: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(merged_df['region'].isin(oceania), 'Oceania','unknown')))))  )

# %%
medalists_df = merged_df[merged_df['Medal'].isin(['Gold', 'Silver', 'Bronze'])]

pivot = pd.pivot_table(merged_df, values=['ID'],
                                columns=['Medal'],
                                index=['continent'],
                                aggfunc='count')
pivot = pivot.reset_index()
sns.countplot(medalists_df['continent'], hue=medalists_df['Medal'])
plt.xticks(rotation=20)
plt.title('DISTRIBUTION OF MEDALS ACROSS THE CONTINENTS')
plt.show()
pivot
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#            continent     ID
# Medal                Bronze  Gold Silver
# 0             Africa    224   174    170
# 1               Asia   1091  1076   1090
# 2             Europe   8907  8030   8663
# 3      North America   2079  3362   2336
# 4            Oceania    607   472    517
# 5      South America    358   244    323
# 6            unknown     25    13     13

# %%
merged_df.fillna(0, inplace=True)

# %% [markdown]
# ## **BEST ATHLETES**

# %%
top_athletes = medalists_df['Name'].value_counts()

top_athletes_df = medalists_df[medalists_df['Name'].isin(top_athletes.index[:10])]

top_athletes_df = top_athletes_df.reset_index(drop=True)

pivot_table = pd.pivot_table(top_athletes_df, values=['ID'],
                                columns=['Medal'],
                                index=['Name', 'region'],
                                aggfunc='count')
pivot_table.fillna(0, inplace=True)

pivot_table['total'] = pivot_table['ID', 'Gold'] + pivot_table['ID', 'Silver'] + pivot_table['ID', 'Bronze']
pivot_table = pivot_table.sort_values('total', ascending=False)

# %%
sns.countplot(top_athletes_df['Name'], hue=top_athletes_df['Medal'])
plt.xticks(rotation=80)
plt.title('DISTRIBUTION OF MEDALS ACROSS THE CONTINENTS')
plt.show()

pivot_table
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#                                                ID              total
# Medal                                      Bronze  Gold Silver
# Name                               region
# Michael Fred Phelps, II            USA        2.0  23.0    3.0  28.0
# Larysa Semenivna Latynina (Diriy-) Russia     4.0   9.0    5.0  18.0
# Nikolay Yefimovich Andrianov       Russia     3.0   7.0    5.0  15.0
# Borys Anfiyanovych Shakhlin        Russia     2.0   7.0    4.0  13.0
# Edoardo Mangiarotti                Italy      2.0   6.0    5.0  13.0
# Ole Einar Bjrndalen                Norway     1.0   8.0    4.0  13.0
# Takashi Ono                        Japan      4.0   5.0    4.0  13.0
# Natalie Anne Coughlin (-Hall)      USA        5.0   3.0    4.0  12.0
# Paavo Johannes Nurmi               Finland    0.0   9.0    3.0  12.0
# Ryan Steven Lochte                 USA        3.0   6.0    3.0  12.0

# %% [markdown]
# The plot above shows that the most decorated player is **Michael Fred Phelps, II** from USA who happens to have the most gold

# %% [markdown]
# ## ANALYSIS IN AFRICA

# %%
africa_df = merged_df[merged_df['continent']== 'Africa'].reset_index(drop=True)

# %%
len(africa_df['region'].unique())
# Out:
# 54

# %% [markdown]
# A total of 54 african countries have participated in the event

# %%
africa_df
# Out:
#            ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 0          48    Abdelhak Aatakni   M  24.0     NaN    64.0  Morocco  MAR
# 1         154     Khadija Abbouda   F  40.0   165.0    57.0  Morocco  MAR
# 2         421   Mohamed Aberhoune   M  23.0   187.0    75.0  Morocco  MAR
# 3         486       Zakaria Aboub   M  20.0   171.0    65.0  Morocco  MAR
# 4         536       Lahcen Abrami   M  22.0     NaN     NaN  Morocco  MAR
# ...       ...                 ...  ..   ...     ...     ...      ...  ...
# 11747  120575     Mamorallo Tjoka   F  23.0   150.0    56.0  Lesotho  LES
# 11748  120575     Mamorallo Tjoka   F  27.0   150.0    56.0  Lesotho  LES
# 11749  122166  M'apotlaki Ts'elho   F  15.0     NaN     NaN  Lesotho  LES
# 11750  122215          Lefa Tsapi   M  23.0   170.0    63.0  Lesotho  LES
# 11751  122299       Mosolesa Tsie   M  20.0   175.0    75.0  Lesotho  LES
#
#              Games  Year  Season         City      Sport  \
# 0      2012 Summer  2012  Summer       London     Boxing
# 1      2008 Summer  2008  Summer      Beijing    Archery
# 2      2012 Summer  2012  Summer       London   Football
# 3      2000 Summer  2000  Summer       Sydney   Football
# 4      1992 Summer  1992  Summer    Barcelona   Football
# ...            ...   ...     ...          ...        ...
# 11747  2008 Summer  2008  Summer      Beijing  Athletics
# 11748  2012 Summer  2012  Summer       London  Athletics
# 11749  1996 Summer  1996  Summer      Atlanta  Athletics
# 11750  1984 Summer  1984  Summer  Los Angeles     Boxing
# 11751  2000 Summer  2000  Summer       Sydney     Boxing
#
#                                         Event Medal   region notes continent
# 0             Boxing Men's Light-Welterweight   NaN  Morocco   NaN    Africa
# 1                  Archery Women's Individual   NaN  Morocco   NaN    Africa
# 2                     Football Men's Football   NaN  Morocco   NaN    Africa
# 3                     Football Men's Football   NaN  Morocco   NaN    Africa
# 4                     Football Men's Football   NaN  Morocco   NaN    Africa
# ...                                       ...   ...      ...   ...       ...
# 11747              Athletics Women's Marathon   NaN  Lesotho   NaN    Africa
# 11748              Athletics Women's Marathon   NaN  Lesotho   NaN    Africa
# 11749  Athletics Women's 4 x 100 metres Relay   NaN  Lesotho   NaN    Africa
# 11750               Boxing Men's Welterweight   NaN  Lesotho   NaN    Africa
# 11751               Boxing Men's Welterweight   NaN  Lesotho   NaN    Africa
#
# [11752 rows x 18 columns]

# %%
top_african_countries = africa_df.groupby('region')['Medal'].count().sort_values(ascending=False)
sns.barplot(top_african_countries.index[:5], top_african_countries.values[:5])
plt.xticks(rotation=45)
plt.title('TOP AFRICAN COUNTRIES WITH MOST MEDALS')
plt.show()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pivo = pd.pivot_table(africa_df, values=['Medal'],
                                columns=['region'],
                                index=['Year'],
                                aggfunc='count')
pivo.columns = pivo.columns.droplevel()
top_african_medalists_df = pivo[['South Africa', 'Kenya', 'Nigeria']]
