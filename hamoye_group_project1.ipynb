# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('athlete_events.csv')

# %%
df1 = pd.read_csv('noc_regions.csv')

# %%
merged_df['Age'].fillna(merged_df['Age'].mean(), inplace=True)

# Fill missing values in 'Height' column with the median
merged_df['Height'].fillna(merged_df['Height'].median(), inplace=True)

# Fill missing values in 'Weight' column with the median
merged_df['Weight'].fillna(merged_df['Weight'].median(), inplace=True)

# Fill missing values in 'region' column with the mode
merged_df['region'].fillna(merged_df['region'].mode()[0], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12116\3175084328.py in <cell line: 1>()
# ----> 1 merged_df['Age'].fillna(merged_df['Age'].mean(), inplace=True)
#       2
#       3 # Fill missing values in 'Height' column with the median
#       4 merged_df['Height'].fillna(merged_df['Height'].median(), inplace=True)
#       5
#
# NameError: name 'merged_df' is not defined

# %%
categorical_col=[]
for column in df.columns:
    if df[column].dtype==object and len(df[column].unique())<=58:
        categorical_col.append(column)
        print(str(column) + str (df[ column].unique()) )
        print("======================================")
# Out:
# Sex['M' 'F']
# ...
# Games['1992 Summer' '2012 Summer' '1920 Summer' '1900 Summer' '1988 Winter'
#  '1992 Winter' '1994 Winter' '1932 Summer' '2002 Winter' '1952 Summer'
#  '1980 Winter' '2000 Summer' '1996 Summer' '1912 Summer' '1924 Summer'
#  '2014 Winter' '1948 Summer' '1998 Winter' '2006 Winter' '2008 Summer'
#  '2016 Summer' '2004 Summer' '1960 Winter' '1964 Winter' '1984 Winter'
#  '1984 Summer' '1968 Summer' '1972 Summer' '1988 Summer' '1936 Summer'
#  '1952 Winter' '1956 Winter' '1956 Summer' '1960 Summer' '1928 Summer'
#  '1976 Summer' '1980 Summer' '1964 Summer' '2010 Winter' '1968 Winter'
#  '1906 Summer' '1972 Winter' '1976 Winter' '1924 Winter' '1904 Summer'
#  '1928 Winter' '1908 Summer' '1948 Winter' '1932 Winter' '1936 Winter'
#  '1896 Summer']
# ...
# Season['Summer' 'Winter']
# ...
# City['Barcelona' 'London' 'Antwerpen' 'Paris' 'Calgary' 'Albertville'
#  'Lillehammer' 'Los Angeles' 'Salt Lake City' 'Helsinki' 'Lake Placid'
# ...

# %%
com_table = df1.merge(df, on='NOC')

# %% [markdown]
# creating a continet column

# %%
# List of countries by continent
europe = ['Albania', 'Andorra', 'Angola', 'Antigua', 'Armenia', 'Austria', 'Azerbaijan', 
          'Belgium', 'Bosnia and Herzegovina', 'Belize', 'Belarus', 'Czech Republic', 'Bulgaria', 
          'Croatia', 'Cyprus', 'Denmark', 'Hungary', 'Iceland', 'Italy', 'Kazakhstan', 'Kosovo', 'Finland',
          'France', 'Georgia', 'Germany', 'Greece', 'Ireland', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta',
          'Latvia', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 
          'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden','Turkey',
          'Switzerland', 'Ukraine', 'UK', 'Macedonia', 'Virgin Islands, British']

africa = ['Angola', 'Algeria', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cape Verde', 'Cameroon', 
          'Democratic Republic of the Congo', 'Chad', 'Central African Republic', 'Republic of Congo',
          'Democratic Republic of the Congo', 'Gabon', 'Gambia', 'Ghana', 'Equatorial Guinea', 'Guinea',
          'Guinea-Bissau', 'Morocco', 'Egypt', 'Kenya', 'Libya', 'Mali', 'Senegal', 'Solomon Islands', 
          'Somalia', 'South Sudan', 'Tunisia', 'Zimbabwe', 'Zambia', 'Sudan', 'Sierra Leone', 'Comoros',
          'Ivory Coast', 'Djibouti', 'Eritrea', 'Swaziland', 'Ethiopia', 'Lesotho', 'Liberia', 'Madagascar',
          'Malawi', 'Mauritania', 'Mauritius', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 
          'Sao Tome and Principe', 'Seychelles', 'South Africa', 'Tanzania', 'Togo', 'Uganda']

asia = ['Afghanistan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Timor-Leste',
        'Georgia', 'India', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Japan', 'Kyrgyzstan', 'Kuwait', 'Laos', 'Lebanon',
        'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'North Korea', 'Oman', 'Pakistan', 'Palestine',
        'Philippines', 'Qatar', 'Saudi Arabia', 'South Korea', 'Syria', 'Taiwan', 'Sri Lanka', 'Tajikistan', 'Thailand', 
         'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen', 'Azerbaijan', 'Indonesia']

north_america = ['Antigua', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Cuba', 'Dominica',
                 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica',
                  'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts', 'Saint Vincent', 'Saint Lucia', 'Trinidad', 
                 'USA', 'Cayman Islands', 'American Samoa', 'Puerto Rico', 'Aruba', 'Bermuda','US']

south_america = ['Argentina', 'Boliva', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay',
                 'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'Curacao']

oceania = ['Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia', 'Nauru', 'New Zealand', 
           'Palau', 'Papua New Guinea', 'Samoa', 'Tonga', 'Cook Islands', 'Individual Olympic Athletes',
           'Vanuatu', 'nan', 'Guam']

# Create a new column 'continent' in the 'df' DataFrame and assign continent values
com_table['continent'] = pd.np.where(com_table['region'].isin(europe), 'Europe',
                pd.np.where(com_table['region'].isin(africa), 'Africa',
                 pd.np.where(com_table['region'].isin(asia), 'Asia',
                pd.np.where(com_table['region'].isin(north_america), 'North America',
                pd.np.where(com_table['region'].isin(south_america), 'South America',
                pd.np.where(com_table['region'].isin(oceania), 'Oceania','unknown')))))  )

# Print the updated DataFrame
print(com_table)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12116\1387220873.py:38: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   com_table['continent'] = pd.np.where(com_table['region'].isin(europe), 'Europe',
# C:\Users\HP\AppData\Local\Temp\ipykernel_12116\1387220873.py:39: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(com_table['region'].isin(africa), 'Africa',
# C:\Users\HP\AppData\Local\Temp\ipykernel_12116\1387220873.py:40: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   pd.np.where(com_table['region'].isin(asia), 'Asia',
# ...

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
com_table = com_table.drop_duplicates().reset_index(drop=True)

# %%
com_table
# Out:
#         NOC       region notes      ID                   Name Sex   Age  \
# 0       AFG  Afghanistan   NaN     502      Ahmad Shah Abouwi   M   NaN
# 1       AFG  Afghanistan   NaN    1076  Jammal-ud-Din Affendi   M  28.0
# 2       AFG  Afghanistan   NaN    1101   Mohammad Anwar Afzal   M   NaN
# 3       AFG  Afghanistan   NaN    1745         Mohammad Aktar   M  17.0
# 4       AFG  Afghanistan   NaN    4628  Mohammad Daoud Anwary   M  22.0
# ...     ...          ...   ...     ...                    ...  ..   ...
# 269377  ZIM     Zimbabwe   NaN  130832         Hillary Wilson   F  15.0
# 269378  ZIM     Zimbabwe   NaN  130832         Hillary Wilson   F  15.0
# 269379  ZIM     Zimbabwe   NaN  130880    Peter Arthur Wilson   M  20.0
# 269380  ZIM     Zimbabwe   NaN  131478  Jennifer "Jenny" Wood   F  16.0
# 269381  ZIM     Zimbabwe   NaN  135497          Lloyd Zvasiya   M  23.0
#
#         Height  Weight         Team        Games  Year  Season       City  \
# ...

# %%
event_unique_values = com_table['region'].unique()
event_unique_values
# Out:
# array(['Afghanistan', 'Curacao', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Antigua', 'Australia', 'Argentina', 'Armenia', 'Aruba',
#        'American Samoa', 'Austria', 'Azerbaijan', 'Bahamas', 'Bangladesh',
#        'Barbados', 'Burundi', 'Belgium', 'Benin', 'Bermuda', 'Bhutan',
#        'Bosnia and Herzegovina', 'Belize', 'Belarus', 'Czech Republic',
#        'Boliva', 'Botswana', 'Brazil', 'Bahrain', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Central African Republic', 'Cambodia', 'Canada',
#        'Cayman Islands', 'Republic of Congo', 'Chad', 'Chile', 'China',
#        'Ivory Coast', 'Cameroon', 'Democratic Republic of the Congo',
#        'Cook Islands', 'Colombia', 'Comoros', 'Cape Verde', 'Costa Rica',
#        'Croatia', 'Greece', 'Cuba', 'Cyprus', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'Eritrea',
#        'El Salvador', 'Spain', 'Estonia', 'Ethiopia', 'Russia', 'Fiji',
# ...

# %%
df1.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# Average Age|Height|Weight

# %%
total_avg = com_table[['Age', 'Height', 'Weight']].mean().plot
total_avg

# %%
total_avg = com_table[['Age', 'Height', 'Weight']].mean()

# Plot the average values
total_avg.plot(kind='bar')

# Add labels and title
plt.xlabel('Attributes')
plt.ylabel('Average')
plt.title('Average Age, Height, and Weight')

# Display the plot
plt.show()
total_avg
# Out:
# Age        25.457542
# Height    175.344234
# Weight     70.708909
# dtype: float64

# %% [markdown]
# Total number perticipant by gender

# %%
sex_counts = com_table['Sex'].value_counts()
colors = ['green', 'red']
sex_counts.plot(kind='bar', color=colors)

plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Value Counts of Sex')

plt.show()

# %% [markdown]
# Total number perticipant |gender | season

# %%
import matplotlib.pyplot as plt
G_season = com_table.groupby('Season')['Sex'].value_counts().sort_values(ascending=False)

colors = ['green', 'red']

G_season.plot(kind='bar', color=colors)

plt.xlabel('Season, Sex')
plt.ylabel('Count')
plt.title('Grouped Value Counts of Sex by Season')

plt.show()

# %% [markdown]
# Total number Medal | season

# %%
G_season=com_table.groupby('Season')['Medal'].value_counts().sort_values(ascending =False)

colors = ['green', 'red']

G_season.plot(kind ='bar', color = colors)
plt.xlabel('Season, Medal')
plt.ylabel('Count')
plt.title('Total number Medal | season')
print(G_season)
# Out:
# Season  Medal
# Summer  Gold      11455
#         Bronze    11405
#         Silver    11208
# Winter  Gold       1913
#         Silver     1896
#         Bronze     1886
# Name: Medal, dtype: int64

# %% [markdown]
# Region with female highest perticipant

# %%
G_subset = com_table[['Sex', 'region']]
G_region = G_subset[G_subset.Sex == 'F'].groupby('region').value_counts().sort_values(ascending=False).head(10)
G_region
# Out:
# region     Sex
# USA        F      5489
# Germany    F      4844
# Russia     F      4105
# Canada     F      3563
# UK         F      3263
# China      F      2992
# Japan      F      2779
# France     F      2761
# Australia  F      2751
# Italy      F      2539
# dtype: int64

# %% [markdown]
# The top 10 events with the highest number of male participants.

# %%
E_subset = com_table[['Sex', 'Event']]
male_E_subset = E_subset[E_subset.Sex == 'M'].groupby('Event').value_counts().sort_values(ascending=False).head(10)
male_E_subset
# Out:
# Event                                   Sex
# Football Men's Football                 M      5733
# Ice Hockey Men's Ice Hockey             M      4762
# Hockey Men's Hockey                     M      3941
# Water Polo Men's Water Polo             M      3348
# Basketball Men's Basketball             M      3270
# Cycling Men's Road Race, Individual     M      2947
# Gymnastics Men's Individual All-Around  M      2500
# Rowing Men's Coxed Eights               M      2423
# Gymnastics Men's Team All-Around        M      2411
# Handball Men's Handball                 M      2264
# dtype: int64

# %% [markdown]
# The top 10 events with the highest number of female participants.

# %%
E_subset = com_table[['Sex', 'Event']]
female_E_subset = E_subset[E_subset.Sex == 'F'].groupby('Event').value_counts().sort_values(ascending=False).head(10)
female_E_subset
# Out:
# Event                                     Sex
# Volleyball Women's Volleyball             F      1543
# Gymnastics Women's Individual All-Around  F      1538
# Gymnastics Women's Balance Beam           F      1530
# Gymnastics Women's Uneven Bars            F      1529
# Gymnastics Women's Floor Exercise         F      1526
# Gymnastics Women's Team All-Around        F      1484
# Hockey Women's Hockey                     F      1459
# Handball Women's Handball                 F      1401
# Gymnastics Women's Horse Vault            F      1336
# Basketball Women's Basketball             F      1256
# dtype: int64

# %% [markdown]
# The top 10 recent female gold winners from Africa.

# %%
gold_winner = com_table[com_table['Medal'] == 'Gold']
africa_gold_winners = gold_winner[gold_winner.continent == 'Africa'].sort_values(by = 'Year',ascending=False).head(10)
africa_gold_winners
# Out:
#         NOC        region notes      ID                        Name Sex   Age  \
# 156259  KEN         Kenya   NaN  116424      Jemima Jelagat Sumgong   F  31.0
# 203199  RSA  South Africa   NaN  108532      Mokgadi Caster Semenya   F  25.0
# 155698  KEN         Kenya   NaN   20525   Vivian Jepkemoi Cheruiyot   F  32.0
# 48955   CIV   Ivory Coast   NaN   21695   Cheick Sallah Ciss Junior   M  22.0
# 155829  KEN         Kenya   NaN   59542  Faith Chepngetich Kibiegon   F  22.0
# 155850  KEN         Kenya   NaN   60589              Eliud Kipchoge   M  31.0
# 203427  RSA  South Africa   NaN  124804           Wayde van Niekerk   M  24.0
# 155878  KEN         Kenya   NaN   60624           Conseslus Kipruto   M  21.0
# 68644   ETH      Ethiopia   NaN    6204             Almaz Ayana Eba   F  24.0
# 156164  KEN         Kenya   NaN  103274        David Lekuta Rudisha   M  27.0
#
#         Height  Weight           Team        Games  Year  Season  \
# ...

# %% [markdown]
# The top 10 recent male gold winners from Africa.

# %%
gold_winner = com_table[com_table['Medal'] == 'Gold']
africa_gold_winners = gold_winner[gold_winner.continent == 'Africa'].sort_values(by = 'Year',ascending=False).head(10)
africa_gold_winners
# Out:
#         NOC        region notes      ID                        Name Sex   Age  \
# 156259  KEN         Kenya   NaN  116424      Jemima Jelagat Sumgong   F  31.0
# 203199  RSA  South Africa   NaN  108532      Mokgadi Caster Semenya   F  25.0
# 155698  KEN         Kenya   NaN   20525   Vivian Jepkemoi Cheruiyot   F  32.0
# 48955   CIV   Ivory Coast   NaN   21695   Cheick Sallah Ciss Junior   M  22.0
# 155829  KEN         Kenya   NaN   59542  Faith Chepngetich Kibiegon   F  22.0
# 155850  KEN         Kenya   NaN   60589              Eliud Kipchoge   M  31.0
# 203427  RSA  South Africa   NaN  124804           Wayde van Niekerk   M  24.0
# 155878  KEN         Kenya   NaN   60624           Conseslus Kipruto   M  21.0
# 68644   ETH      Ethiopia   NaN    6204             Almaz Ayana Eba   F  24.0
# 156164  KEN         Kenya   NaN  103274        David Lekuta Rudisha   M  27.0
#
#         Height  Weight           Team        Games  Year  Season  \
# ...

# %% [markdown]
# The top 10 earliest female gold winners from Africa.

# %%
gold_winner = com_table[com_table['Medal'] == 'Gold']
africa_gold_winners = gold_winner[gold_winner.continent == 'Africa']
Female_africa_gold_winners = africa_gold_winners[africa_gold_winners.Sex == 'F'].sort_values(by = 'Year',ascending=False).tail(10)
Female_africa_gold_winners
# Out:
#         NOC        region notes      ID                                  Name  \
# 269200  ZIM      Zimbabwe   NaN   50854                   Susan "Sue" Huggett
# 269371  ZIM      Zimbabwe   NaN  128977                 Linda Margaret Watson
# 269166  ZIM      Zimbabwe   NaN   39559                   Maureen Jean George
# 269155  ZIM      Zimbabwe   NaN   32681                         Sarah English
# 269139  ZIM      Zimbabwe   NaN   25651          Patricia Joan "Trish" Davies
# 269133  ZIM      Zimbabwe   NaN   23570                 Gillian "Gill" Cowley
# 269100  ZIM      Zimbabwe   NaN   20673               Alexandra "Sandy" Chick
# 269098  ZIM      Zimbabwe   NaN   19962                 Elizabeth "Liz" Chase
# 202401  RSA  South Africa   NaN   46205     Joan Cynthia Harrison (-Breetzke)
# 202016  RSA  South Africa   NaN   14616  Esther Cornelia Brand (van Heerden-)
#
#        Sex   Age  Height  Weight          Team        Games  Year  Season  \
# ...

# %% [markdown]
# The top 10 earliest male gold winners from Africa.

# %%
mgold_winner = com_table[com_table['Medal'] == 'Gold']
mafrica_gold_winners = mgold_winner[mgold_winner.continent == 'Africa']
earl_male_africa_gold_winners = mafrica_gold_winners[mafrica_gold_winners.Sex == 'M'].sort_values(by = 'Year',ascending=False).tail(10)
earl_male_africa_gold_winners
# Out:
#         NOC        region notes      ID                              Name Sex  \
# 203260  RSA  South Africa   NaN  112442  William Alexander "Willie" Smith   M
# 203150  RSA  South Africa   NaN  103253         Bevil Gordon d'Urban Rudd   M
# 203505  RSA  South Africa   NaN  128134     Clarence Leonard "Sal" Walker   M
# 203073  RSA  South Africa   NaN   99274              Louis Bosman Raymond   M
# 202781  RSA  South Africa   NaN   77230       Kennedy Kane "Ken" McArthur   M
# 202679  RSA  South Africa   NaN   69255             Rudolph Ludewyk Lewis   M
# 202599  RSA  South Africa   NaN   60928      Harold Austin "Harry" Kitson   M
# 203558  RSA  South Africa   NaN  131024         Charles Lyndhurst Winslow   M
# 203559  RSA  South Africa   NaN  131024         Charles Lyndhurst Winslow   M
# 203504  RSA  South Africa   NaN  128130    Reginald Edgar "Reggie" Walker   M
#
#          Age  Height  Weight          Team        Games  Year  Season  \
# ...

# %% [markdown]
# Region with highset gold winner

# %%
region_gold_winner = com_table[com_table['Medal'] == 'Gold']['region'].value_counts().head(10)
# africa_gold_winners = gold_winner[gold_winner.continent == 'Africa'].sort_values(by = 'Year',ascending=True)
region_gold_winner
# Out:
# USA        2638
# Russia     1599
# Germany    1301
# UK          677
# Italy       575
# France      499
# Sweden      479
# Canada      463
# Hungary     432
# Norway      378
# Name: region, dtype: int64

# %% [markdown]
# The top 10 regions in Africa with the highest of gold winners.

# %%
Aregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
africa_gold_winners = Aregion_gold_winner[Aregion_gold_winner['continent'] == 'Africa']
africa_region_gold_winners = africa_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)
colors = ['red', 'green', 'green', 'orange', 'purple', 'yellow', 'red', 'magenta', 'green', 'pink']
ax = africa_region_gold_winners.plot(kind='bar', color=colors)
ax.set_xlabel('Region')
ax.set_ylabel('Count')
ax.set_title('Top 10 African Region Gold Winners')

# Display the plot
plt.show()
africa_region_gold_winners
# Out:
# Kenya           34
# South Africa    32
# Nigeria         23
# Ethiopia        22
# Cameroon        20
# Zimbabwe        17
# Egypt            7
# Morocco          6
# Algeria          5
# Tunisia          3
# Name: region, dtype: int64

# %% [markdown]
# The top 10 regions in Europe with the highest number of gold winners.

# %%
Eregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
Europe_gold_winners = Eregion_gold_winner[Eregion_gold_winner.continent == 'Europe']
Europe_region_gold_winners = Europe_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)
Europe_region_gold_winners
# Out:
# Russia         1599
# Germany        1301
# UK              677
# Italy           575
# France          499
# Sweden          479
# Hungary         432
# Norway          378
# Netherlands     287
# Finland         198
# Name: region, dtype: int64

# %%
Eregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
Europe_gold_winners = Eregion_gold_winner[Eregion_gold_winner['continent'] == 'Europe']
Europe_region_gold_winners = Europe_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)

Europe_region_gold_winners.plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 10 European Region Gold Winners')
plt.axis('equal')
plt.show()
Europe_region_gold_winners
# Out:
# Russia         1599
# Germany        1301
# UK              677
# Italy           575
# France          499
# Sweden          479
# Hungary         432
# Norway          378
# Netherlands     287
# Finland         198
# Name: region, dtype: int64

# %% [markdown]
# The top 10 regions in Asia with the highest number of gold winners.

# %%
ASregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
asia_gold_winners = ASregion_gold_winner[ASregion_gold_winner['continent'] == 'Asia']
asia_region_gold_winners = asia_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)

colors = sns.color_palette('Set3')
asia_region_gold_winners.plot(kind='bar', color=colors)
plt.xlabel('Region')
plt.ylabel('Number of Gold Winners')
plt.title('Top 10 Asian Region Gold Winners')

plt.show()
asia_region_gold_winners
# Out:
# China          351
# Japan          247
# South Korea    221
# India          138
# Pakistan        42
# Iran            18
# North Korea     16
# Indonesia       11
# Uzbekistan      10
# Thailand         9
# Name: region, dtype: int64

# %% [markdown]
# The top 10 regions in North America with the highest number of gold winners.

# %%
NAregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
North_America_gold_winners = NAregion_gold_winner[NAregion_gold_winner.continent == 'North America']
North_America_region_gold_winners = North_America_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)
North_America_region_gold_winners
# Out:
# USA                   2638
# Canada                 463
# Cuba                   164
# Jamaica                 38
# Mexico                  30
# Bahamas                 14
# Trinidad                 7
# Dominican Republic       3
# Costa Rica               1
# Grenada                  1
# Name: region, dtype: int64

# %% [markdown]
# The top 10 regions in South America with the highest number of gold winners.

# %%
SAregion_gold_winner = com_table[com_table['Medal'] == 'Gold']
SouthAme_gold_winners = SAregion_gold_winner[SAregion_gold_winner.continent == 'South America']
South_America_region_gold_winners = SouthAme_gold_winners['region'].value_counts().sort_values(ascending=False).head(10)
South_America_region_gold_winners
# Out:
# Brazil       109
# Argentina     91
# Uruguay       31
# Colombia       5
# Chile          3
# Venezuela      2
# Ecuador        1
# Peru           1
# Suriname       1
# Name: region, dtype: int64

# %%
South America
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_12116\1112252321.py", line 1
#     South America
#           ^
# SyntaxError: invalid syntax

# %%
region_con_Medal=com_table.groupby('Medal')['continent'].value_counts().sort_values(ascending =False)
region_con_Medal
# Out:
# Medal   continent
# Bronze  Europe           8907
# Silver  Europe           8655
# Gold    Europe           8027
#         North America    3362
# Silver  North America    2336
# Bronze  North America    2079
#         Asia             1091
# Silver  Asia             1090
# Gold    Asia             1076
# Bronze  Oceania           607
# Silver  Oceania           517
# Gold    Oceania           472
# Bronze  South America     358
# Silver  South America     323
# Gold    South America     244
# Bronze  Africa            224
# Gold    Africa            174
# Silver  Africa            170
# Bronze  unknown            25
# Gold    unknown            13
# Silver  unknown            13
# Name: continent, dtype: int64

# %%
com_table.head()

# %% [markdown]
# Most Apper individual in the game

# %%
com_table[['Name', 'region', 'continent']].value_counts().head(10)
# Out:
# Name                         region      continent
# Heikki Ilmari Savolainen     Finland     Europe           39
# Joseph "Josy" Stoffel        Luxembourg  Europe           38
# Ioannis Theofilakis          Greece      Europe           36
# Takashi Ono                  Japan       Asia             33
# Andreas Wecker               Germany     Europe           32
# Alexandros Theofilakis       Greece      Europe           32
# Johann "Hans" Sauter         Austria     Europe           31
# Alfred August "Al" Jochim    USA         North America    31
# Michel Mathiot               France      Europe           31
# Karl Tore William Thoresson  Sweden      Europe           30
# dtype: int64

# %% [markdown]
# Top 10 Most Gold winner individual in the game

# %%
individuals = com_table[['Name', 'region','Age', 'Medal','Year']]

i_gold_winner = individuals[individuals['Medal'] == 'Gold'].groupby('Name').value_counts().sort_values(ascending =False).head(10)
i_gold_winner
# Out:
# Name                            region   Age   Medal  Year
# Michael Fred Phelps, II         USA      23.0  Gold   2008    8
# Mark Andrew Spitz               USA      22.0  Gold   1972    7
# Vitaly Venediktovich Shcherbo   Russia   20.0  Gold   1992    6
# Kristin Otto                    Germany  22.0  Gold   1988    6
# Michael Fred Phelps, II         USA      19.0  Gold   2004    6
# Nedo Nadi                       Italy    25.0  Gold   1920    5
# Paavo Johannes Nurmi            Finland  26.0  Gold   1924    5
# Matthew Nicholas "Matt" Biondi  USA      22.0  Gold   1988    5
# Anton Heida                     USA      25.0  Gold   1904    5
# Michael Fred Phelps, II         USA      31.0  Gold   2016    5
# dtype: int64

# %% [markdown]
# Top 10 Most Gold winner individual in the game from Africa and the year

# %%
individuals = com_table[['Name', 'region','Age','Sex', 'Medal', 'continent', 'Year']]
Africa_gold_ind_winner = individuals[individuals['continent']== 'Africa']
Afri_gold_winner = Africa_gold_ind_winner[Africa_gold_ind_winner['Medal'] == 'Gold'].groupby('Name').value_counts().sort_values(ascending =False).head(10)

Afri_gold_winner
# Out:
# Name                       region        Age   Sex  Medal  continent  Year
# Kenenisa Bekele Beyecha    Ethiopia      26.0  M    Gold   Africa     2008    2
# Penelope "Penny" Heyns     South Africa  21.0  F    Gold   Africa     1996    2
# Charles Lyndhurst Winslow  South Africa  23.0  M    Gold   Africa     1912    2
# Miruts Yifter              Ethiopia      36.0  M    Gold   Africa     1980    2
# Tirunesh Dibaba Keneni     Ethiopia      23.0  F    Gold   Africa     2008    2
# Hicham El Guerrouj         Morocco       29.0  M    Gold   Africa     2004    2
# Moulay Brahim Boutayeb     Morocco       21.0  M    Gold   Africa     1988    1
# Mobi Patrick Oparaku       Nigeria       19.0  M    Gold   Africa     1996    1
# Oussama Mellouli           Tunisia       24.0  M    Gold   Africa     2008    1
# Modeste M'Bami             Cameroon      17.0  M    Gold   Africa     2000    1
# dtype: int64

# %%
event_counts = com_table['Year'].value_counts().sort_values(ascending =False)
event_counts
# Out:
# 1992    16376
# 1988    14649
# 2000    13798
# 1996    13745
# 2016    13656
# 2008    13566
# 2004    13421
# 2012    12884
# 1972    11947
# 1984    11574
# 1976    10498
# 1968    10473
# 1964     9480
# 1952     9351
# 1960     9230
# 1980     8937
# 1948     7382
# 1936     7146
# 1956     6382
# 1924     5570
# 1928     5238
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1994     3160
# 1908     3069
# 1932     2817
# 1900     1898
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, dtype: int64

# %%
trend  = com_table[['Medal', 'continent', 'Year']]
trend.loc[:, 'Medal'] = trend['Medal'].fillna('no_medals')
trend['Year'] = pd.to_datetime(trend['Year'], format='%Y')

trend_filtered = trend[trend['continent'] != 'unknown']

medal_counts = trend_filtered.groupby(['Year', 'continent'])['Medal'].count().unstack()
medal_counts.plot(kind='line', figsize=(10, 6))

plt.title('Medal Count Trend by Region')
plt.xlabel('Year')
plt.ylabel('Medal Count')

plt.legend()

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12116\2812822709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trend.loc[:, 'Medal'] = trend['Medal'].fillna('no_medals')
# C:\Users\HP\AppData\Local\Temp\ipykernel_12116\2812822709.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trend['Year'] = pd.to_datetime(trend['Year'], format='%Y')

# %% [markdown]
# the total number of gold, silver, and bronze medals won,

# %%
individuals = com_table[['Name', 'region', 'Medal']]

bmedal_counts = individuals.groupby('Medal').size()

gold_count = medal_counts.get('Gold', 0)
silver_count = medal_counts.get('Silver', 0)
bronze_count = medal_counts.get('Bronze', 0)

print("Total Gold Medals:", gold_count)
print("Total Silver Medals:", silver_count)
print("Total Bronze Medals:", bronze_count)
# Out:
# Total Gold Medals: 13368
# Total Silver Medals: 13104
# Total Bronze Medals: 13291

# %% [markdown]
# Top Ten Sports by Gold Medals:

# %%
gold_medals = com_table[com_table['Medal'] == 'Gold']

gold_medal_counts = gold_medals.groupby('Sport').size()

top_ten_sports = gold_medal_counts.nlargest(10)

print("Top Ten Sports by Gold Medals:")
print(top_ten_sports)
# Out:
# Top Ten Sports by Gold Medals:
# Sport
# Athletics     1339
# Swimming      1098
# Rowing         978
# Gymnastics     791
# Fencing        594
# Hockey         518
# Football       515
# Ice Hockey     508
# Sailing        447
# Cycling        424
# dtype: int64

# %% [markdown]
# gold_medal_counts = gold_medals.groupby('Event').size()

# %%
gold_medals = com_table[com_table['Medal'] == 'Gold']

gold_medal_counts = gold_medals.groupby('Event').size()

top_ten_sports = gold_medal_counts.nlargest(10)

print("Top Ten Events by Gold Medals:")
print(top_ten_sports)
# Out:
# Top Ten Events by Gold Medals:
# Event
# Football Men's Football             414
# Ice Hockey Men's Ice Hockey         407
# Hockey Men's Hockey                 360
# Water Polo Men's Water Polo         287
# Gymnastics Men's Team All-Around    249
# Rowing Men's Coxed Eights           244
# Basketball Men's Basketball         234
# Handball Men's Handball             194
# Volleyball Men's Volleyball         166
# Hockey Women's Hockey               158
# dtype: int64

# %%
com_table.head(2)
# Out:
#    NOC       region notes    ID                   Name Sex   Age  Height  \
# 0  AFG  Afghanistan   NaN   502      Ahmad Shah Abouwi   M   NaN     NaN
# 1  AFG  Afghanistan   NaN  1076  Jammal-ud-Din Affendi   M  28.0     NaN
#
#    Weight         Team        Games  Year  Season       City   Sport  \
# 0     NaN  Afghanistan  1956 Summer  1956  Summer  Melbourne  Hockey
# 1     NaN  Afghanistan  1936 Summer  1936  Summer     Berlin  Hockey
#
#                  Event Medal continent
# 0  Hockey Men's Hockey   NaN      Asia
# 1  Hockey Men's Hockey   NaN      Asia

# %% [markdown]
# Average height\age\height of gold medal winners

# %%
gold_medal_winners = com_table[com_table['Medal'] == 'Gold']

# Calculate the average age of the gold medal winners
average_height = gold_medal_winners['Height'].mean()
average_age = gold_medal_winners['Age'].mean()
average_weight = gold_medal_winners['Weight'].mean()


print("Average height of gold medal winners:", average_height)
print("Average_age of gold medal winners:", average_age)
print("Average height of gold medal winners:", average_weight)
# Out:
# Average height of gold medal winners: 177.89789333839437
# Average_age of gold medal winners: 25.900385749943272
# Average height of gold medal winners: 74.18389739588413

# %%
# Assuming you have a DataFrame named 'com_table' with columns: 'Medal', 'Sport', 'Height', 'Age', 'Weight'

# Filter the DataFrame for gold medal winners
gold_medal_winners = com_table[com_table['Medal'] == 'Gold']

# Group the gold medal winners by sport and calculate the average height, average age, and average weight
grouped_data = gold_medal_winners.groupby('Sport').agg({'Height': 'mean', 'Age': 'mean', 'Weight': 'mean'})

# Print the grouped data
print("Average height, age, and weight of gold medal winners by sport:")
print(grouped_data)
# Out:
# Average height, age, and weight of gold medal winners by sport:
#                       Height        Age     Weight
# Sport
# Aeronautics              NaN  26.000000        NaN
# Alpine Skiing     173.918033  24.174825  72.785124
# Alpinism                 NaN  38.812500        NaN
# Archery           173.630769  30.696429  71.140625
# Art Competitions  176.000000  41.250000  75.000000
# ...                      ...        ...        ...
# Tug-Of-War        180.500000  30.184211  93.750000
# Volleyball        187.170886  25.720497  80.544304
# Water Polo        185.708772  26.323699  86.081784
# Weightlifting     166.748634  25.138889  81.151442
# Wrestling         172.597484  25.918919  76.261006
#
# [66 rows x 3 columns]
